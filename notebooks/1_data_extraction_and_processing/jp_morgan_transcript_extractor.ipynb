# %% [markdown]
# # Setup, Constants, and Imports

# %%
import os
import sys
import logging

# %% [markdown]
# ## Notebook Configs

# %%
IS_COLAB = False # Update this if running in Google Colab
OUTPUT_PROCESSED_FILES = True

# %% [markdown]
# ## Constants

# %%
REPO_URL = "https://github.com/EErlando/Quarterly-Bytes.git"
REPO_NAME = "src" 
REPO_BRANCH = "KEW_jpmorgan_eda" # CHANGE THIS IF NEED
ALL_TRANSCRIPTS_PATH = "data/raw/JP Morgan/Transcripts"
NOTEBOOK_DIR = "1_data_extraction_and_processing" # Update this to your notebook directory

# %% [markdown]
# ## Clone and Pull Latest from Repository - Colab Specific

# %%
if IS_COLAB:
    # !git config pull.rebase false
    if os.path.exists(REPO_NAME):
        print(f"Directory '{REPO_NAME}' already exists. Pulling latest changes...")
        # %cd {REPO_NAME}
        # !git pull origin {REPO_BRANCH} --quiet
        # %cd ..
    else:
        print(f"Cloning repository into '{REPO_NAME}'...")
        # !git clone --quiet --branch {REPO_BRANCH} {REPO_URL} {REPO_NAME}
        print("Clone complete.")

    sys.path.append('/content/src/')
    # %cd /content/src/
    # %pip install -r requirements.txt
else:
    # %pip install -r requirements.txt
    if os.path.basename(os.getcwd()) == NOTEBOOK_DIR:
        os.chdir('../../')

logging.basicConfig(level=logging.ERROR, format='%(levelname)s: %(message)s')
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Local Imports

# %%
from src.utils.pdf_utils import extract_transcripts_pdf_df_from_dir, BankType

# %% [markdown]
# # Get Transcript Files

# %%
qna_df, discussion_df = extract_transcripts_pdf_df_from_dir(ALL_TRANSCRIPTS_PATH, BankType.JPMORGAN)
# Out:
# doing block
# found operator: 0
# found operator: 1
# overflow line
# found operator: 2
# found operator: 3
# found operator: 4
# overflow line
# found operator: 5
# overflow line
# found operator: 6
# found operator: 7
# overflow line
# overflow line
# found operator: 8
# found operator: 9
# found operator: 10
# doing block
# found operator: 0
# found operator: 1
# found operator: 2
# found operator: 3
# found operator: 4
# found operator: 5
# found operator: 6
# found operator: 7
# found operator: 8
# found operator: 9
# found operator: 10
# found operator: 11
# found operator: 12
# found operator: 13
# found operator: 14
# doing block
# found operator: 0
# found operator: 1
# found operator: 2
# found operator: 3
# found operator: 4
# found operator: 5
# found operator: 6
# found operator: 7
# found operator: 8
# found operator: 9
# found operator: 10
# found operator: 11
# found operator: 12
# doing block
# found operator: 0
# found operator: 1
# found operator: 2
# found operator: 3
# found operator: 4
# overflow line
# found operator: 5
# found operator: 6
# found operator: 7
# found operator: 8
# found operator: 9
# found operator: 10
# found operator: 11
# found operator: 12
# doing block
# found operator: 0
# found operator: 1
# found operator: 2
# found operator: 3
# found operator: 4
# found operator: 5
# found operator: 6
# found operator: 7
# found operator: 8
# overflow line
# found operator: 9
# found operator: 10
# found operator: 11
# doing block
# found operator: 0
# found operator: 1
# found operator: 2
# overflow line
# found operator: 3
# overflow line
# overflow line
# found operator: 4
# found operator: 5
# found operator: 6
# found operator: 7
# found operator: 8
# found operator: 9
# overflow line
# found operator: 10
# found operator: 11
# found operator: 12
# found operator: 13
# doing block
# found operator: 0
# found operator: 1
# found operator: 2
# found operator: 3
# found operator: 4
# found operator: 5
# found operator: 6
# found operator: 7
# found operator: 8
# found operator: 9
# found operator: 10
# doing block
# found operator: 0
# found operator: 1
# found operator: 2
# found operator: 3
# found operator: 4
# found operator: 5
# found operator: 6
# found operator: 7
# found operator: 8
# found operator: 9
# found operator: 10
# found operator: 11
# found operator: 12
# doing block
# found operator: 0
# found operator: 1
# found operator: 2
# found operator: 3
# found operator: 4
# found operator: 5
# found operator: 6
# found operator: 7
# found operator: 8
# found operator: 9
# found operator: 10
# doing block
# found operator: 0
# found operator: 1
# found operator: 2
# found operator: 3
# found operator: 4
# found operator: 5
# found operator: 6
# found operator: 7
# found operator: 8
# found operator: 9
# found operator: 10
# found operator: 11
# found operator: 12
# found operator: 13
# doing block
# found operator: 0
# found operator: 1
# found operator: 2
# found operator: 3
# found operator: 4
# found operator: 5
# found operator: 6
# overflow line
# found operator: 7
# found operator: 8
# found operator: 9
# found operator: 10
# found operator: 11
# doing block
# found operator: 0
# found operator: 1
# found operator: 2
# found operator: 3
# overflow line
# found operator: 4
# found operator: 5
# found operator: 6
# found operator: 7
# overflow line
# found operator: 8
# found operator: 9
# found operator: 10
# doing block
# found operator: 0
# found operator: 1
# found operator: 2
# found operator: 3
# found operator: 4
# found operator: 5
# found operator: 6
# found operator: 7
# found operator: 8
# found operator: 9
# found operator: 10
# found operator: 11
# found operator: 12

# %%
qna_df.head(30)
# Out:
#     question_order  question_answer_group_id           speaker  \
# 0                0                         1  John E. McDonald
# 1                1                         1     Jeremy Barnum
# 2   Okay. And as my follow up, could you give us s...  2022       1
# 3   Yeah. I guess I would direct you to my comment...  2022       1
# 4                                       Okay. Thanks.  2022       1
# 5                                      Thanks, John .  2022       1
# 6   Hi. Thanks. Good morning. Jeremy, just wanted ...  2022       1
# 7   Yeah. Thanks. So let me just give some high le...  2022       1
# 8   And just a follow up there too, is there anyth...  2022       1
# 9   Yeah. I think – I guess in general, we haven't...  2022       1
# 10                              Okay. Thanks, Jeremy.  2022       1
# 11                                             Yeah .  2022       1
# 12                                  Hi. Good morning.  2022       1
# 13                                    Morning, Betsy.  2022       1
# 14  I had a question for Jamie. In your annual let...  2022       1
# 15  Yeah. So, Betsy, that number, the double -digi...  2022       1
# 16  Okay. And getting to double digits is over the...  2022       1
# 17  I wasn't meaning to put a timeframe on it. But...  2022       1
# 18  Okay. And then just the follow up here is on t...  2022       1
# 19                                        No, no, no.  2022       1
# 20                                                No.  2022       1
# 21  We don't look at it that way, like we're reinv...  2022       1
# 22  Yeah. I mean, I think fundamentally, we have h...  2022       1
# 23                     Okay . Great. Thanks for that.  2022       1
# 24                             Hey. Good morning. So…  2022       1
# 25                                          Hi Steve.  2022       1
# 26  ...wanted to start off with a question on QT. ...  2022       1
# 27  Hey, Steve. So this is a fun question. So let'...  2022       1
# 28                    And then I’ll simplify for you.  2022       1
# 29  Yeah, exactly. Okay. So look, I think we've ta...  2022       1

# %%
qna_df.year.value_counts()
# Out:
# year
# 2022    374
# 2023    336
# 2024    278
# 2025    108
# Name: count, dtype: int64

# %%
qna_df.role.value_counts()
# Out:
# role
# Analyst                               499
# Chief Financial Officer               363
# Chairman & Chief Executive Officer    234
# Name: count, dtype: int64

# %%
discussion_df.head()
# Out:
#          speaker                                role               company  \
# 0  Jeremy Barnum             Chief Financial Officer  JPMorgan Chase & Co.
# 1  Jeremy Barnum             Chief Financial Officer  JPMorgan Chase & Co.
# 2  Jeremy Barnum             Chief Financial Officer  JPMorgan Chase & Co.
# 3    Jamie Dimon  Chairman & Chief Executive Officer  JPMorgan Chase & Co.
# 4  Jeremy Barnum             Chief Financial Officer  JPMorgan Chase & Co.
#
#                                              content  year quarter
# 0  Thanks, operator. Good morning, everyone. The ...  2022       1
# 1  Thanks, operator. Good morning, everyone. The ...  2022       2
# 2  Thank you very much. Good morning, everyone. A...  2022       3
# 3  Yeah, Jeremy, thank you very much. Hello, ever...  2022       3
# 4  Yeah. Thanks, Jamie. Let's go ahead and open u...  2022       3

# %%
if OUTPUT_PROCESSED_FILES:
    qna_df.to_csv('data/processed/JP Morgan/qna_df.csv', index=False)
    discussion_df.to_csv('data/processed/JP Morgan/discussion_df.csv', index=False)
    print("Processed files saved successfully.")
# Out:
# Processed files saved successfully.
