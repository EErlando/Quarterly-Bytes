# %% [markdown]
# # Setup, Constants, and Imports

# %%
import os
import sys
import logging

# %% [markdown]
# ## Notebook Configs

# %%
IS_COLAB = False # Update this if running in Google Colab
OUTPUT_PROCESSED_FILES = True

# %% [markdown]
# ## Constants

# %%
REPO_URL = "https://github.com/EErlando/Quarterly-Bytes.git"
REPO_NAME = "src"
REPO_BRANCH = "pdf_extraction_and_restructuring" # CHANGE THIS IF NEED
ALL_TRANSCRIPTS_PATH = "data/raw/Goldman Sachs/Transcripts"
NOTEBOOK_DIR = "1_data_extraction_and_processing" # Update this to your notebook directory

# %% [markdown]
# ## Clone and Pull Latest from Repository - Colab Specific

# %%
if IS_COLAB:
    # !git config pull.rebase false
    if os.path.exists(REPO_NAME):
        print(f"Directory '{REPO_NAME}' already exists. Pulling latest changes...")
        # %cd {REPO_NAME}
        # !git pull origin {REPO_BRANCH} --quiet
        # %cd ..
    else:
        print(f"Cloning repository into '{REPO_NAME}'...")
        # !git clone --quiet --branch {REPO_BRANCH} {REPO_URL} {REPO_NAME}
        print("Clone complete.")

    sys.path.append('/content/src/')
    # %cd /content/src/
    # !pip install -r requirements.txt
else:
    if os.path.basename(os.getcwd()) == NOTEBOOK_DIR:
        os.chdir('../../')

logging.basicConfig(level=logging.ERROR, format='%(levelname)s: %(message)s')
# Out:
# fatal: not in a git directory
# Directory 'src' already exists. Pulling latest changes...
# /content/src
# /content
# /content/src
# Requirement already satisfied: PyPDF2==3.0.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 1)) (3.0.1)

# %% [markdown]
# ## Local Imports

# %%
from src.utils.pdf_utils import extract_transcripts_pdf_df_from_dir, BankType

# %% [markdown]
# # Get Transcript Files

# %%
qna_df, discussion_df = extract_transcripts_pdf_df_from_dir(ALL_TRANSCRIPTS_PATH, BankType.GOLDMAN_SACHS)
# Out:
# WARNING:root:Could not extract text from page 31 of 'data/raw/Goldman Sachs/Transcripts/4q23_earnings_transcript.pdf'. It might contain images or scanned content.
# WARNING:root:Could not extract text from page 30 of 'data/raw/Goldman Sachs/Transcripts/4q22_earnings_transcript.pdf'. It might contain images or scanned content.

# %%
qna_df.head()
# Out:
#    question_order  question_answer_group_id        speaker      role  \
# 0               0                         0   Glenn Schorr  question
# 1               1                         0  Denis Coleman    answer
# 2               2                         0   Glenn Schorr  question
# 3               3                         0  Denis Coleman    answer
# 4               4                         0   Glenn Schorr  question
#
#   content_type                                            content quarter  \
# 0     question   hi, thanks very much. i apologize if i missed...       2
# 1       answer   thanks, glenn. it’ s denis. let me take that ...       2
# 2     question   okay . very much appreciated. and then one qu...       2
# 3       answer   what i would say in terms of the overall advi...       2
# 4     question                                     thanks, denis.       2
#
#    year
# 0  2022
# 1  2022
# 2  2022
# 3  2022
# 4  2022

# %%
discussion_df.head()
# Out:
#          speaker                                role  \
# 0    Carey Halio          [Head, Investor Relations]
# 1  David Solomon  [Chairman, Chief Executive Ofﬁcer]
# 2  Denis Coleman            [Chief Financial Ofﬁcer]
# 3  David Solomon  [Chairman, Chief Executive Ofﬁcer]
# 4  Denis Coleman            [Chief Financial Ofﬁcer]
#
#                                              content quarter  year
# 0   Good morning. This is Carey Halio, Head of In...       2  2022
# 1   Thanks, Carey and good morning everybody . Th...       2  2022
# 2   Thank you, David. Good morning. Let’ s start ...       2  2022
# 3   Thank you, operator , and good morning, every...       1  2024
# 4   Thank you, David. Good morning. Let's start w...       1  2024

# %%
if OUTPUT_PROCESSED_FILES:
    qna_df.to_csv('data/processed/Goldman Sachs/qna_df.csv', index=False)
    discussion_df.to_csv('data/processed/Goldman Sachs/discussion_df.csv', index=False)
    print("Processed files saved successfully.")
# Out:
# Processed files saved successfully.
